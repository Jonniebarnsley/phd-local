# %%
import xarray as xr
from slepy import SLECalculator

# %%
file = xr.open_dataset("/Users/jonniebarnsley/Downloads/matts_inversion_inputs.nc")

# %%
file
# Out:
# <xarray.Dataset> Size: 2GB
# Dimensions:        (x: 6144, y: 6144)
# Coordinates:
#   * x              (x) float64 49kB 500.0 1.5e+03 ... 6.142e+06 6.144e+06
#   * y              (y) float64 49kB 500.0 1.5e+03 ... 6.142e+06 6.144e+06
# Data variables:
#     crs            int32 4B ...
#     time_of_array  float64 8B ...
#     umod           (y, x) float64 302MB ...
#     umodc          (y, x) float64 302MB ...
#     btrc           (y, x) float64 302MB ...
#     velx           (y, x) float64 302MB ...
#     vely           (y, x) float64 302MB ...
# Attributes: (12/14)
#     Conventions:         CF-1.7
#     component_0:         umod
#     component_1:         umodc
#     component_2:         btrc
#     component_3:         velx
#     component_4:         vely
#     ...                  ...
#     num_components:      5
#     num_levels:          1
#     crs_origin_x:        0.0
#     crs_origin_y:        0.0
#     dx:                  1000.0
# ...

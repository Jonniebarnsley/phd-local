# %%
import xarray as xr
import matplotlib.pyplot as plt

# %%
file = xr.open_dataset('/Users/jonniebarnsley/Downloads/ppe/Cwshelf/ppe_run15_Cwshelf_0lev.nc')
C = file.isel(time=-1).Cwshelf
C.plot()

# %%
bedmachine = xr.open_dataset('/Users/jonniebarnsley/data/BedMachine/BedMachine_antarctica_v3_bisicles_1km.nc')
coarse = bedmachine.coarsen(x=8, y=8).mean()
bed = coarse.bed
thk = coarse.thickness
bed.plot()

# %%
test =

# %%
plt.scatter(coarse.data.flatten(), C.data.flatten(), s=0.01, alpha=0.02)

# %%
len(C.data.flatten())
# Out:
# 589824

# %%
file = xr.open_dataset("~/Downloads/test.nc")
file
# Out:
# <xarray.Dataset> Size: 113MB
# Dimensions:        (x: 768, y: 768)
# Coordinates:
#   * x              (x) float64 6kB 4e+03 1.2e+04 2e+04 ... 6.132e+06 6.14e+06
#   * y              (y) float64 6kB 4e+03 1.2e+04 2e+04 ... 6.132e+06 6.14e+06
# Data variables: (12/26)
#     crs            int32 4B ...
#     time_of_array  float64 8B ...
#     X0             (y, x) float64 5MB ...
#     X1             (y, x) float64 5MB ...
#     C              (y, x) float64 5MB ...
#     Cwshelf        (y, x) float64 5MB ...
#     ...             ...
#     gradJMuCoef    (y, x) float64 5MB ...
#     velc           (y, x) float64 5MB ...
#     divuhc         (y, x) float64 5MB ...
#     thickness      (y, x) float64 5MB ...
#     Z_base         (y, x) float64 5MB ...
#     Z_surface      (y, x) float64 5MB ...
# Attributes: (12/51)
#     Conventions:             CF-1.7
#     component_0:             X0
#     component_1:             X1
#     component_10:            yVelo
# ...

# %%
file.Cwshelf.plot()

# %%
file = xr.open_dataset("~/Downloads/last_iter_30yr.nc")

# %%
file.Cwshelf.plot()

# %%
from phd.local.lib.CG import get_fm_fp

fm, fp = get_fm_fp('/Users/jonniebarnsley/Downloads/CG_aC_1e8.txt')

plt.plot(fm)

# %%
plt.plot(fm)
plt.yscale('log')

# %%
from phd.local.lib.CG import get_fm_fp
import matplotlib.pyplot as plt

# %%
fm, fp = get_fm_fp('/Users/jonniebarnsley/Downloads/high-both_CG.txt')

# %%
plt.plot(fm, label='$f_m$')
plt.plot(fp, label='$f_p$')
plt.yscale('log')
plt.title('very high regularisation')
plt.ylabel('2-norm')
plt.xlabel('iteration')
plt.legend()
plt.ylim(0, 1e20)
# Out:
# /var/folders/d9/3tqzv4xj1sx00nng1hd597500000gn/T/ipykernel_21299/3683127544.py:8: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   plt.ylim(0, 1e20)
# (4.3022174119978456e+16, 1e+20)
